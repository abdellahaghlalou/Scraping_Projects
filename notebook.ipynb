# %% [markdown]
# # projet de abdellah aghlalou :

# %%
from bs4 import BeautifulSoup as bfs 
from urllib.request import urlopen , Request
import pandas as pd
import numpy as np

# %% [markdown]
# # web scraping ( avito ) :

# %% [markdown]
# avito.com is a e-commerce site that contains millions of products of differents products.

# %%
headers='name,time,price,city,category\n'
f=open('products.csv','w', encoding='utf-8')
f.write(headers)
for i in tqdm.trange(1,3004):
        req=Request("https://www.avito.ma/fr/maroc/?o="+str(i), headers={'User-Agent':''})
        A=urlopen(req)
        pagehtml=A.read()
        A.close()
        page_soup=bfs(pagehtml,"html.parser")
        contents=page_soup.findAll("div",{'class':['item', 'li-hover', 'bump']})
        for i in range(len(contents)) :
            # scraper le temps d'annonce
            temps=page_soup.findAll("abbr",{"class" : 'text-center'})
            time=temps[i].text 
            if "Aujourd'hui" in time :
                time=time.replace("Aujourd'hui","03Apl")
            if 'Hier' in time :
                time=time.replace("Hier","02Apl")
            # scraper le prix d'annonce
            prices=page_soup.findAll("div",{"class" : "item-price"})
            prix=prices[i].span.text.replace(' ','').replace('DH','')
            # scraper la ville
            city=((contents[i].span.text).split(',')[1]).split('-')[0].replace('\n','')
            # scraper la categorie
            category=(contents[i].span.text.replace('\n','')).split(',')[0].split('-')
            if len(category)==2:
                category=category[1]
            else :
                category=category[0]
            # scraper le nom
            name=contents[i].h2.a.text.replace('\n','')
            f.write(name+','+time.replace('\n','').replace(' ','')+','+prix.replace('\n','')+','+city.replace(' ','')+','+category+'\n')
f.close()

# %%
contents

# %% [markdown]
# # chargement des donnes :

# %%
df=pd.read_csv('products.csv')

# %% [markdown]
# # infos sur les donnes :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105140 entries, 0 to 105139
# Data columns (total 5 columns):
# name        105140 non-null object
# time        105140 non-null object
# price       75226 non-null float64
# city        105140 non-null object
# category    105140 non-null object
# dtypes: float64(1), object(4)
# memory usage: 4.0+ MB

# %%
df.head()
# Out:
#                                       name        time    price        city  \
# 0                    suzuki celerio -2012   03Apl12:14  57000.0  Casablanca
# 1                               شقة للرهن   03Apl12:13  30000.0   Marrakech
# 2           جهاز تصفية مياه الشرب المنزلي   03Apl12:13      NaN         Fès
# 3   Tv nikai led hd 24p récepteur intégré   03Apl12:13   1200.0  Casablanca
# 4            Maserati Ghibli diesel -2016   03Apl12:13      NaN  Casablanca
#
#                        category
# 0                      Voitures
# 1                  Appartements
# 2  Electroménager et Vaisselles
# 3                   Télévisions
# 4                      Voitures

# %%
df.describe()
# Out:
#               price
# count  7.522600e+04
# mean   2.726806e+05
# std    1.096466e+07
# min    1.000000e+00
# 25%    7.000000e+02
# 50%    2.400000e+03
# 75%    1.340000e+04
# max    1.800000e+09

# %% [markdown]
# # statistiques et visualisation

# %%
import seaborn 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %% [markdown]
# -1- l'annonce la plus cher :

# %%
df[df['price']==df.max()['price']]
# Out:
#                     name        time         price    city            category
# 86411   مزرعة 225 هكتار   14Mar02:06  1.800000e+09  Meknès  Terrains et Fermes

# %% [markdown]
# -2-nombre d'annonce par ville et la ville qui le plus grand nombre d'annonce:

# %%
a=df.groupby('city').count().sort_values(by='category',ascending=False).head()
a.reset_index(inplace=True)
a
# Out:
#          city   name   time  price  category
# 0  Casablanca  32386  32386  20979     32386
# 1       Rabat  12440  12440   9227     12440
# 2   Marrakech   9423   9423   7097      9423
# 3      Tanger   6922   6922   5557      6922
# 4      Agadir   6242   6242   4516      6242

# %%
g = seaborn.catplot(x="city", y="category", data=a,height=6, kind="bar")
g.set_xlabels("Top 5 des villes")
g.set_ylabels("Nombre d'annonces")
plt.title("annonces par villes")
# Out:
# Text(0.5, 1, 'annonces par villes')

# %% [markdown]
# -3-nombre d'annonce par category

# %%
df.groupby('category').count()
# Out:
#                                        name   time  price   city
# category
#  Appartements                            26     26     22     26
#  Bureaux et Plateaux                      3      3      2      3
#  Camions                                  5      5      4      5
#  Colocations                              1      1      1      1
#  Engins BTP                               2      2      1      2
#  Locations de vacances                   12     12     12     12
#  Magasins                                 1      1      1      1
#  Maisons et Villas                        4      4      4      4
#  Terrains et Fermes                       7      7      5      7
# AUTRES                                  686    686    515    686
# Accessoires informatique et Gadgets    4918   4918   4443   4918
# Animaux                                2568   2568   1668   2568
# Appareils photo et Caméras             2032   2032   1006   2032
# Appartements                           8172   8172   6980   8172
# Art et Collections                      635    635    369    635
# Autre Immobilier                         84     84     59     84
# Autres                                  108    108     66    108
# Bateaux                                  63     63     49     63
# Bureaux et Plateaux                     596    596    496    596
# Business et Affaires commerciales       211    211    114    211
# Camions                                 813    813    515    813
# Chaussures                              976    976    857    976
# Colocations                             346    346    308    346
# Electroménager et Vaisselles           3669   3669   2183   3669
# Engins Agricole                         128    128     79    128
# Engins BTP                              175    175    103    175
# Equipements pour enfant et bébé         913    913    762    913
# Films                                    55     55     45     55
# Image & Son                            1495   1495   1087   1495
# Instruments de Musique                  450    450    383    450
# Jardin et Outils de bricolage          1014   1014    713   1014
# Jeux vidéo et Consoles                 2265   2265   1959   2265
# Locations de vacances                  2591   2591   2392   2591
# Magasins                               1154   1154    862   1154
# Maisons et Villas                      1943   1943   1411   1943
# Matériels Professionnels               9977   9977   2068   9977
# Meubles et Décoration                  5258   5258   3931   5258
# Montres et Bijoux                      1015   1015    872   1015
# Motos                                  2847   2847   2297   2847
# Ordinateurs de bureau                  8576   8576   8466   8576
# Ordinateurs portables                  5627   5627   4984   5627
# Pièces et Accessoires pour véhicules   4658   4658   1521   4658
# Produits de beauté                      897    897    787    897
# Remorques et Caravanes                   38     38     26     38
# Sacs et Accessoires                     356    356    318    356
# Sports et Loisirs                       779    779    648    779
# Stocks et Vente en gros                 737    737    418    737
# Tablettes                               435    435    375    435
# Terrains et Fermes                     2306   2306   1331   2306
# Téléphones                             7421   7421   6575   7421
# Télévisions                             663    663    609    663
# Voitures                              13282  13282   9832  13282
# Voyages et Billetterie                   34     34     34     34
# Vélos                                  1245   1245    825   1245
# Vêtements                               756    756    636    756
# Vêtements pour enfant et bébé            42     42     37     42

# %%
f, ax = plt.subplots(figsize=(7, 10))
seaborn.countplot(y="category", data=df.head(100), color="c")

# %%
fig, ax = plt.subplots(figsize=(20, 10), subplot_kw=dict(aspect="equal"))
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} )".format(pct, absolute)


wedges, texts, autotexts = ax.pie(list(b['name']), autopct=lambda pct: func(pct, list(b['name'])),
                                  textprops=dict(color="w"))

ax.legend(wedges, list(b['category']),
          title="category",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=15, weight="bold")
ax.set_title("Matplotlib bakery: A pie")
plt.show()

# %%
df.head()
# Out:
#                                          name         time      price  \
# 0          maison 105 m2 commercial M 'hamid   31 Mar12:39  1500000.0
# 1              Tout les marque pneu a partir   31 Mar12:38      450.0
# 2          Appartement en Vente à Mohammedia   31 Mar12:38   580000.0
# 3   Audi SQ8 tdi Quattro S-line diesel -2020   31 Mar12:38        NaN
# 4               Toyota Prado VX diesel -2008   31 Mar12:38        NaN
#
#          city                              category
# 0   Marrakech                     Maisons et Villas
# 1  Casablanca  Pièces et Accessoires pour véhicules
# 2  Mohammedia                          Appartements
# 3  Casablanca                              Voitures
# 4   Marrakech                              Voitures

# %% [markdown]
# -3- Annonces sans prix :

# %%
df[df['price'].isnull()].count()
# Out:
# name        29004
# time        29004
# price           0
# city        29004
# category    29004
# dtype: int64

# %%
df[np.isfinite(df['price'])]
# Out:
#                                               name        time      price  \
# 0                            suzuki celerio -2012   03Apl12:14    57000.0
# 1                                       شقة للرهن   03Apl12:13    30000.0
# 3           Tv nikai led hd 24p récepteur intégré   03Apl12:13     1200.0
# 5                      W Table et chaise coiffeur   03Apl12:13      600.0
# 6             فيلا رائعة مفروشة ما بين ملعب الكرة   03Apl12:13  3300000.0
# ...                                            ...         ...        ...
# 105134                               غرفة نوم خشب   11Mar17:45     9000.0
# 105135                                     valise   11Mar17:45      400.0
# 105136   HP Pavilion HP 14 i5 8ème NVIDIA GeForce   11Mar17:45     6800.0
# 105137                 bmw e60 520i serie 5 -2004   11Mar17:44    62000.0
# 105139                 pôles en porssolenne vrais   11Mar17:44      700.0
#
#               city                      category
# 0       Casablanca                      Voitures
# 1        Marrakech                  Appartements
# 3       Casablanca                   Télévisions
# 5            Rabat         Meubles et Décoration
# 6           Tanger             Maisons et Villas
# ...            ...                           ...
# 105134   Marrakech         Meubles et Décoration
# 105135       Rabat           Sacs et Accessoires
# 105136         Fès         Ordinateurs portables
# 105137      Tanger                      Voitures
# 105139  Casablanca  Electroménager et Vaisselles
#
# [75226 rows x 5 columns]

# %% [markdown]
# -5-annonce plus cher par category :

# %%
ancpluscher=df[['price','category']].groupby('category').max()
ancpluscher
# Out:
#                                              price
# category
#  Appartements                         2.200000e+06
#  Autre Immobilier                              NaN
#  Bureaux et Plateaux                  4.500000e+03
#  Camions                              1.080000e+05
#  Colocations                          1.200000e+03
#  Engins Agricole                      3.070000e+05
#  Engins BTP                           2.100000e+05
#  Locations de vacances                6.000000e+02
#  Magasins                             1.100000e+04
#  Maisons et Villas                    7.600000e+06
#  Terrains et Fermes                   2.700000e+05
# AUTRES                                6.000000e+05
# Accessoires informatique et Gadgets   6.489410e+08
# Animaux                               6.672788e+08
# Appareils photo et Caméras            2.300230e+07
# Appartements                          2.600000e+08
# Art et Collections                    1.000000e+06
# Autre Immobilier                      4.000000e+07
# Autres                                4.000000e+05
# Bateaux                               9.500000e+05
# Bureaux et Plateaux                   4.700470e+07
# Business et Affaires commerciales     6.400000e+07
# Camions                               3.600000e+07
# Chaussures                            2.700000e+04
# Colocations                           7.007260e+08
# Electroménager et Vaisselles          5.000000e+04
# Engins Agricole                       7.000000e+05
# Engins BTP                            2.600000e+07
# Equipements pour enfant et bébé       1.500400e+09
# Films                                 6.500000e+03
# Image & Son                           6.240840e+08
# Instruments de Musique                8.000000e+06
# Jardin et Outils de bricolage         5.000000e+05
# Jeux vidéo et Consoles                1.800000e+08
# Locations de vacances                 8.200000e+05
# Magasins                              1.500000e+08
# Maisons et Villas                     1.000000e+09
# Matériels Professionnels              3.000000e+06
# Meubles et Décoration                 5.400000e+05
# Montres et Bijoux                     5.500000e+04
# Motos                                 4.000000e+05
# Ordinateurs de bureau                 2.990000e+05
# Ordinateurs portables                 1.500000e+05
# Pièces et Accessoires pour véhicules  1.629000e+05
# Produits de beauté                    2.500000e+04
# Remorques et Caravanes                4.500000e+05
# Sacs et Accessoires                   1.250000e+04
# Sports et Loisirs                     1.111111e+06
# Stocks et Vente en gros               6.000000e+05
# Tablettes                             2.100000e+04
# Terrains et Fermes                    1.800000e+09
# Téléphones                            6.500000e+04
# Télévisions                           2.700000e+04
# Voitures                              8.500000e+06
# Voyages et Billetterie                1.750000e+04
# Vélos                                 3.000000e+04
# Vêtements                             1.500000e+04
# Vêtements pour enfant et bébé         3.300000e+06
